# %%
# %sh
# print current working directory to confirm the repo path
pwd

# %%
# %sh
# rename the folder using git mv, so git tracks it as a rename
git mv winery-ecommerce/data-cleaning winery-ecommerce/01-data-cleaning

# %%
# %sh
# check git status to confirm the rename was staged
git status
